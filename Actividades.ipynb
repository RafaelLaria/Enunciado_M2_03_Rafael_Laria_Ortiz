# %% [markdown]
# Ejercicio 1

# %%
n = input("Escriba su número = ")
print(n)
print(type(n))
# Out:
# 10
# <class 'str'>

# %%
n = int((input("Escriba su entero = ")))
print(n)
print(type(n))
# Out:
# 10
# <class 'int'>

# %%
n = float(input("Escriba su flotante = "))
print(n)
print(type(n))
# Out:
# 3.14
# <class 'float'>

# %% [markdown]
# Ejercicio 2
