# %% [markdown]
# Ejercicio 1

# %%
n = input("Escriba su número = ")
print(n)
print(type(n))
# Out:
# 10
# <class 'str'>

# %%
n = int((input("Escriba su entero = ")))
print(n)
print(type(n))
# Out:
# 10
# <class 'int'>

# %%
n = float(input("Escriba su flotante = "))
print(n)
print(type(n))
# Out:
# 3.14
# <class 'float'>

# %% [markdown]
# Ejercicio 2

# %%
numero = int(input("Escribe tu entero"))
print("{:05d}".format(numero))

decimal = float(input("Escribe tu flotante"))
print("{:05.3f}".format(decimal))
# Out:
# 00010
# 3.124

# %% [markdown]
# Ejercicio 3

# %%
altura = float(input("Escriba la altura = "))
peso = float(input("Escriba el peso = "))
print("La altura es de {} metros y el peso es de {} KG".format(altura, peso))
# Out:
# La altura es de 1.8 metros y el peso es de 80.0 KG
